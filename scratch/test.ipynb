# %%
# %%bash
# cd ..
#
# # ./ns3 clean 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" > scratch/agg-reno-100.log
# # ./ns3 configure --disable-werror 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" >> scratch/agg-reno-100.log
# ./ns3 run scratch/innetwork-test.cc -- --vsize=200 --topotype=1  2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" > scratch/agg-reno-1110.log
# #./ns3 run scratch/innetwork-test.cc -- --vsize=3000 --topotype=1 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" > scratch/agg-reno-100.log
# #./ns3 run scratch/tcp-test.cc  2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" > scratch/tcp-test.log

# %%
# %%bash
# cd ..
# ./ns3 clean 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" > scratch/quic-agg-debug.log
# ./ns3 configure --disable-werror 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" >> scratch/quic-agg-debug.log
# ./ns3 build 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" >> scratch/quic-agg-debug.log

# %%
# %%bash
# # export LD_LIBRARY_PATH=/home/dd/ns-3-quic-agg-zhuoxu/ns-allinone-3.42/ns-3.42/build/lib:$LD_LIBRARY_PATH
# # su root
# # Zhuxu: should not use absolute path
# # cd /home/dd/ns-3-quic-agg-zhuoxu/ns-allinone-3.42/ns-3.42
# # Zhuoxu: go into the ns3 directory
# cd ..
# # Zhuoxu: use the sed -r "s/\x1B\[[0-9;]*[mK]//g" expression to remove ANSI characters from the output
# # ./ns3 clean 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" > scratch/agg-reno-100.log
# # ./ns3 configure --disable-werror 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" >> scratch/agg-reno-100.log
# ./ns3 run scratch/innetwork-test.cc -- --vsize=2000 --topotype=1  2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g" > scratch/agg-reno-100.log
#
# printenv
# # process the log
# # Zhuoxu: Becareful of the $NF, do not use hard code. Otherwise, the time value will not be extracted correctly.
# grep 'Innetwork aggregation completed' scratch/agg-reno-2000.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with reno as default congestion control algorithm."
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=2000 --cc=bbr --topotype=1 > scratch/agg-reno-bbr-2000.log 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g"
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-reno-bbr-100.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with bbr as default congestion control algorithm."
# rm tmptimes times
# Out:
# SHELL=/bin/bash
# PYTHONUNBUFFERED=1
# PYTHON_FROZEN_MODULES=on
# ELECTRON_RUN_AS_NODE=1
# PWD=/home/dd/ns-3-quic-agg-zhuoxu/ns-allinone-3.42/ns-3.42
# LOGNAME=dd
# XDG_SESSION_TYPE=tty
# VSCODE_ESM_ENTRYPOINT=vs/workbench/api/node/extensionHostProcess
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING=1
# MOTD_SHOWN=pam
# HOME=/home/dd
# LANG=en_US.UTF-8
# LS_COLORS=
# SSL_CERT_DIR=/usr/lib/ssl/certs
# FORCE_COLOR=1
# PYDEVD_USE_FRAME_EVAL=NO
# VSCODE_AGENT_FOLDER=/home/dd/.vscode-server
# CLICOLOR=1
# VSCODE_L10N_BUNDLE_LOCATION=
# CLICOLOR_FORCE=1
# SSH_CONNECTION=10.7.8.180 54045 192.168.1.183 22
# LESSCLOSE=/usr/bin/lesspipe %s %s
# XDG_SESSION_CLASS=user
# VSCODE_HANDLES_SIGPIPE=true
# TERM=xterm-color
# LESSOPEN=| /usr/bin/lesspipe %s
# USER=dd
# GIT_PAGER=cat
# PYTHONIOENCODING=utf-8
# SHLVL=1
# PAGER=cat
# VSCODE_CWD=/home/dd
# XDG_SESSION_ID=212
# MPLBACKEND=module://matplotlib_inline.backend_inline
# LD_LIBRARY_PATH=/home/dd/ns-3-quic-agg-zhuoxu/ns-allinone-3.42/ns-3.42/build/lib
# XDG_RUNTIME_DIR=/run/user/1000
# SSL_CERT_FILE=/usr/lib/ssl/certs/ca-certificates.crt
# SSH_CLIENT=10.7.8.180 54045 22
# VSCODE_CLI_REQUIRE_TOKEN=bc843799-bb95-4ea6-a74f-f896801af36e
# XDG_DATA_DIRS=/usr/local/share:/usr/share:/var/lib/snapd/desktop
# BROWSER=/home/dd/.vscode-server/cli/servers/Stable-f1a4fb101478ce6ec82fe9627c43efbf9e98c813/server/bin/helpers/browser.sh
# PATH=/bin:/home/dd/.vscode-server/cli/servers/Stable-f1a4fb101478ce6ec82fe9627c43efbf9e98c813/server/bin/remote-cli:/home/dd/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/home/dd/.vscode-server/cli/servers/Stable-f1a4fb101478ce6ec82fe9627c43efbf9e98c813/server/bin/remote-cli:/home/dd/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin
# DBUS_SESSION_BUS_ADDRESS=unix:path=/run/user/1000/bus
# VSCODE_NLS_CONFIG={"userLocale":"en","osLocale":"en","resolvedLanguage":"en","defaultMessagesFile":"/home/dd/.vscode-server/cli/servers/Stable-f1a4fb101478ce6ec82fe9627c43efbf9e98c813/server/out/nls.messages.json","locale":"en","availableLanguages":{}}
# VSCODE_HANDLES_UNCAUGHT_ERRORS=true
# OLDPWD=/home/dd/ns-3-quic-agg-zhuoxu/ns-allinone-3.42/ns-3.42/scratch
# VSCODE_IPC_HOOK_CLI=/run/user/1000/vscode-ipc-1d7a8f77-3fc5-4fe8-b49a-0ee79d552575.sock
# _=/bin/printenv
# grep: scratch/agg-reno-2000.log: No such file or directory
# Average time = 0 ms for hierarchical aggregation with reno as default congestion control algorithm.
# Error while terminating subprocess (pid=893508):
# grep: scratch/agg-reno-bbr-100.log: No such file or directory
# Average time = 0 ms for hierarchical aggregation with bbr as default congestion control algorithm.

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=400 --topotype=1 > scratch/agg-reno-400.log 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g"
# # process the log
# # since there are some format problems, here we use $13 instead of $6
# grep 'Innetwork aggregation completed' scratch/agg-reno-400.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with reno as default congestion control algorithm."
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=400 --cc=bbr --topotype=1 > scratch/agg-reno-bbr-400.log 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g"
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-reno-bbr-400.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with bbr as default congestion control algorithm."
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=800 --topotype=1 > scratch/agg-reno-800.log 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g"
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-reno-800.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with reno as default congestion control algorithm."
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=800 --cc=bbr --topotype=1 > scratch/agg-bbr-800.log 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g"
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-bbr-800.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with bbr as default congestion control algorithm."
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000 --topotype=1 > scratch/agg-reno-1000.log 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g"
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-reno-1000.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with reno as default congestion control algorithm."
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000 --cc=bbr --topotype=1 > scratch/agg-reno-bbr-1000.log 2>&1 | sed -r "s/\x1B\[[0-9;]*[mK]//g"
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-reno-bbr-1000.log | awk '{print $NF}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with bbr as default congestion control algorithm."
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000 --topotype=1 > scratch/agg-reno-10001.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-reno-10001.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with reno as default congestion control algorithm."
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000 --cc=bbr --topotype=1 > scratch/agg-bbr-10001.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-bbr-10001.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with bbr as default congestion control algorithm."
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=2000 --topotype=1 > scratch/agg-reno-2000.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-reno-2000.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with reno as default congestion control algorithm."
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=2000 --cc=bbr --topotype=1 > scratch/agg-bbr-2000.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/agg-bbr-2000.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for hierarchical aggregation with bbr as default congestion control algorithm."
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=400 --topotype=0 > scratch/dir-reno-400.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-reno-400.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000 --topotype=0 > scratch/dir-reno-10001.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-reno-10001.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000  --cc=bbr --topotype=0 > scratch/dir-bbr-10001.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-bbr-10001.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000 --topotype=0 > scratch/dir-reno-1000.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-reno-1000.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=1000 --cc=bbr --topotype=0 > scratch/dir-bbr-1000.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-bbr-1000.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=100 --cc=bbr --topotype=0 > scratch/dir-bbr-100.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-bbr-100.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=100 --topotype=0 > scratch/dir-reno-100.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-reno-100.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times

# %%
# %%bash
# # su root
# cd ..
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=400 --cc=bbr --topotype=0 > scratch/dir-bbr-400.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-bbr-400.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for bbr with direct topo"
# rm tmptimes times
#
# ./ns3 run scratch/innetwork-test.cc -- --vsize=400 --topotype=0 > scratch/dir-reno-400.log 2>&1
# # process the log
# grep 'Innetwork aggregation completed' scratch/dir-reno-400.log | awk '{print $6}' | sed 's/ms//' > tmptimes
# #delete first record, this record is inaccurate
# sed '1d' tmptimes > times
# # calculate avg
# avg=$(awk '{sum += $1; count += 1} END {if (count > 0) print sum / count; else print 0}' times)
# echo "Average time = $avg ms for reno with direct topo"
# rm tmptimes times
# Out:
# Average time = 0 ms for bbr with direct topo
# Average time = 0 ms for reno with direct topo
